# %%
import os
import sys
import torch
from torchvision import transforms
from PIL import Image 
import matplotlib.pyplot as plt
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pwd
# Out:
# /home/lev-wsl/projects/cv2021_project

# %%
ROOT_PATH= '/home/lev-wsl/projects/cv2021_project/'
DATASET_ROOT_PATH = ROOT_PATH + 'Assigment4_datasets/'
FAKES_DATASET_PATH = DATASET_ROOT_PATH + 'fakes_dataset/'
SYNTHETICS_DATASET_PATH = DATASET_ROOT_PATH + 'synthetic_dataset/'
CODE_PATH = ROOT_PATH + 'solution/'
sys.path.append(CODE_PATH)
# %cd {CODE_PATH}
# Out:
# /home/lev-wsl/projects/cv2021_project/solution

# %%
# %cat {CODE_PATH+'plot_samples_of_faces_datasets.py'}
# Out:
# """Plot samples from the Deepfakes and Synthetic Faces datasets."""
# import os
# import random
# import matplotlib.pyplot as plt
#
# from common import FIGURES_DIR
# from utils import load_dataset
#
#
# def normalize(image):
#     """Normalize an image pixel values to [0, ..., 1]."""
#     return (image - image.min()) / (image.max() - image.min())
#
# def plot_samples():
#     """Load the Deepfakes and Synthetic Faces datasets, sample real and fake
#     images from them and plot them in a single image."""
#     # create deepfakes dataset
#     fakes_dataset_train = load_dataset('fakes_dataset', 'train')
#     # sample indices of real and fake images
#     real_image_idx = random.choice(range(int(len(fakes_dataset_train) / 2)))
#     fake_image_idx = random.choice(range(int(len(fakes_dataset_train) / 2),
#                                          len(fakes_dataset_train)))
#     images_samples = plt.figure()
#     plt.subplot(2, 2, 1)
#     plt.imshow(normalize(
# ...

# %%
import solution
from solution.faces_dataset import FacesDataset, LABELS
from solution.plot_samples_of_faces_datasets import plot_samples

# %%
# !pwd
# Out:
# /home/lev-wsl/projects/cv2021_project/solution

# %%
# !ls ..
# Out:
# Assignment4_datasets  solution

# %%
import random
from utils import load_dataset

# %%
plot_samples()
